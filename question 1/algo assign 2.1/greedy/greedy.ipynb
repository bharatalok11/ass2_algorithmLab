# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('ObservationGreedy.csv')
df
# Out:
#     Vertices  Avg.Time Taken
# 0          3            0.00
# 1          4            0.00
# 2          5            0.00
# 3          6            0.06
# 4          7            0.00
# 5          8            0.12
# 6          9            0.02
# 7         10            0.12
# 8         11            0.00
# 9         12            0.00
# 10        13            0.00
# 11        14            0.00
# 12        15            0.00
# 13        16            0.00
# 14        17            0.00
# 15        18            0.12
# 16        19            0.00
# 17        20            0.00
# 18        21            0.00
# 19        22            0.00
# 20        23            0.00
# 21        24            0.02
# 22        25            0.02
# 23        26            0.02
# 24        27            0.04
# 25        28            0.00
# 26        29            0.02
# 27        30            0.02
# 28        31            0.00
# 29        32            0.04
# 30        33            0.04
# ...

# %%
print(df.columns)
# Out:
# Index(['Vertices', 'Avg.Time Taken'], dtype='object')

# %%
vertices = df['Vertices']
avg_time_taken = df['Avg.Time Taken']

# %%
plt.figure(figsize=(10, 6))
plt.plot(vertices, avg_time_taken, label='Avg. Time Taken (Greedy approach)', marker='o')
plt.xlabel('Number of Vertices')
plt.ylabel('Average Time Taken (ms)')
plt.title('Comparison of Average Time Taken for Greedy approach')
plt.legend()
plt.show()
